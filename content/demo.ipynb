# %% [markdown]
# # Glue + Xeus-Python in JupyterLite
#
# This notebook is bundled into the JupyterLite site at build time.

# %%
import sys
print('Python:', sys.version)

# %%
import glue_jupyter
print('glue-jupyter:', getattr(glue_jupyter, '__version__', 'unknown'))

# %% [markdown]
# If `glue-jupyter` fails to import, it usually means one of its dependencies isn't available for the `emscripten-wasm32` platform. In that case, try pinning a different version or moving a pure-Python subset to `pip:` (experimental) in `environment.yml`.

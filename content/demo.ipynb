# %%
from glue.core import Data
from glue_jupyter import jglue
from glue_jupyter.bqplot.scatter import BqplotScatterView

# %%
app = jglue()

# %%
from random import randint
N = 100
x = [randint(0, 100) for _ in range(N)]
y = [randint(-100, 100) for _ in range(N)]
z = [randint(0, 500) for _ in range(N)]
data = Data(x=x, y=y, z=z, label="Test Data")
app.data_collection.append(data)

# %%
viewer = app.new_data_viewer(BqplotScatterView, data=data)
# Out:
# LayoutWidget(controls={'toolbar_selection_tools': BasicJupyterToolbar(template=Template(template='<template>\n…

# %%
viewer.figure.marks[-1]
# Out:
# Lines(colors=['#595959'], interactions={'hover': 'tooltip'}, opacities=[0.8], scales={'x': LinearScale(allow_p…

# %%
# viewer.figure.marks = viewer.figure.marks[:1] + viewer.figure.marks[2:]

# %%
# viewer.figure.marks = viewer.figure.marks + [mark]
